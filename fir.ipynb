# %%
file = open("note.txt", 'r')
content = file.read()
print(content)
# Out:
# My name is Samreen fathima Sanaullah

# %%
file = open("note.txt", 'w')
file.write("My name is Samreen Fathima Sanaullah, My father name is Sanaullah")
file.close()

# %%
file = open("note.txt", "a")
file.write("The name is always beautiful.\n")
file.write("The name become a soon AI Architect field.\n")
file.close()

# %%
with open("note.txt", 'r') as f:
    content = f.read()
    print(content)
# Out:
# My name is Samreen Fathima Sanaullah, My father name is SanaullahThe name is always beautiful.
# The name become a soon AI Architect field.

# %%
import os

os.listdir()
# Out:
# ['.env',
#  'AI_Interviewer.py',
#  'assistant.py',
#  'Aysnc.ipynb',
#  'fir.ipynb',
#  'FirstAgent.ipynb',
#  'Flask_Interview.py',
#  'Interview.py',
#  'notepad.txt',
#  'pydanticfun.ipynb',
#  'requirement.txt',
#  'start',
#  'team_state.json',
#  'venv']
